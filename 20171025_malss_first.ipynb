# %%
import sys; sys.path.append('./modules')
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
import csv
import matplotlib.pyplot as plt
import seaborn as sns
from malss import MALSS
from mymodule import name_classifier
from mymodule import func
# %matplotlib inline

# %%
df = pd.read_csv("train.csv")
df = func(df)
print(df.dtypes)
plt.figure(figsize=(10, 8)) #heatmap size
sns.heatmap(df.corr(), annot=True, cmap='plasma')
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Sex              int64
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# miss             int64
# master           int64
# mr               int64
# mrs              int64
# dtype: object

# %%
cls = MALSS('classification',
            shuffle=True, standardize=True, n_jobs=16,
            random_state=0, lang='jp', verbose=True)
y = df["Survived"]
del df["Survived"]
cls.fit(df, y, 'tmp/survived')
cls.generate_module_sample('tmp/su rvived/survived.py')
# Out:
# Set data.
# Choose algorithm.
#     Support Vector Machine (RBF Kernel)
#     Random Forest
#     Support Vector Machine (Linear Kernel)
#     Logistic Regression
#     Decision Tree
#     k-Nearest Neighbors
# Analyze. (take some time)
#     Support Vector Machine (RBF Kernel)
#     Random Forest
#     Support Vector Machine (Linear Kernel)
#     Logistic Regression
#     Decision Tree
#     k-Nearest Neighbors
# Make report.
#     Support Vector Machine (RBF Kernel)
#     Random Forest
#     Support Vector Machine (Linear Kernel)
#     Logistic Regression
#     Decision Tree
#     k-Nearest Neighbors
# Done.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-22-287691761233> in <module>()
#       5 del df["Survived"]
#       6 cls.fit(df, y, 'tmp/survived')
# ----> 7 cls.generate_module_sample('tmp/su rvived/survived.py')
#
# ...

# %% [markdown]
# Support Vector Machine (Linear Kernel) [Back To Top]
#
# グリッドサーチによるハイパーパラメータチューニング結果
#
# C	交差検証（非入れ子式）スコア
# （f1_weighted）	偏差
# 0.1	0.854	0.004
# 1	0.843	0.004
# 10	0.831	0.015
# 100	0.824	0.014

# %%
cls = MALSS('classification',
            shuffle=True, standardize=True, n_jobs=8,
            random_state=0, lang='jp', verbose=True)
df = pd.read_csv("train.csv")
df = func(df)
df = df[pd.notnull(df['Age'])]
df["Sex"] = df["Sex"].astype(int)
print(df.dtypes)
y = df["Age"]
del df["Age"]

cls.fit(df, y, 'tmp/age')
cls.generate_module_sample('tmp/age/regression.py')
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Sex              int64
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# miss             int64
# master           int64
# mr               int64
# mrs              int64
# dtype: object
# Set data.
# Choose algorithm.
#     Support Vector Machine (RBF Kernel)
#     Random Forest
#     Support Vector Machine (Linear Kernel)
#     Logistic Regression
#     Decision Tree
#     k-Nearest Neighbors
# Analyze. (take some time)
#     Support Vector Machine (RBF Kernel)
# /Users/sho.kohara/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_split.py:597: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=3.
#   % (min_groups, self.n_splits)), Warning)
# ...
