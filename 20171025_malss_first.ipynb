# %%
import sys; sys.path.append('./modules')
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
import csv
import matplotlib.pyplot as plt
import seaborn as sns
from malss import MALSS
from mymodule import name_classifier
from mymodule import func
# %matplotlib inline
# Out:
# /home/sho/.pyenv/versions/anaconda3-5.0.0/lib/python3.6/site-packages/matplotlib/__init__.py:1405: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %%
df = pd.read_csv("train.csv")
df = func(df)
print(df.dtypes)
plt.figure(figsize=(10, 8)) #heatmap size
sns.heatmap(df.corr(), annot=True, cmap='plasma')
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Sex              int64
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# master           int64
# mrs              int64
# mr               int64
# miss             int64
# dtype: object

# %%
cls = MALSS('classification',
            shuffle=True, standardize=True, n_jobs=16,
            random_state=0, lang='jp', verbose=True)
y = df["Survived"]
del df["Survived"]
cls.fit(df, y, 'tmp/survived')
cls.generate_module_sample('tmp/survived.py')

# %% [markdown]
# Support Vector Machine (Linear Kernel) [Back To Top]
#
# グリッドサーチによるハイパーパラメータチューニング結果
#
# C	交差検証（非入れ子式）スコア
# （f1_weighted）	偏差
# 0.1	0.854	0.004
# 1	0.843	0.004
# 10	0.831	0.015
# 100	0.824	0.014
