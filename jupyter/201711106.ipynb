# %%
# %matplotlib inline

# %%
# %load_ext heat
# Out:
# The heat extension is already loaded. To reload it, use:
#   %reload_ext heat

# %%
# %%heat
# import sys; sys.path.append('./modules')
# import pandas as pd
# import numpy
# from sklearn.ensemble import RandomForestClassifier
# import csv
# import matplotlib.pyplot as plt
# import seaborn as sns
# from malss import MALSS
# from mymodule import name_classifier
# from mymodule import func
# from sklearn.preprocessing import Imputer
# import better_exceptions
# better_exceptions.MAX_LENGTH = None
#
# def mapAge(ldf):
#     print(ldf["Age"].median())
#     ldf["Age"].nan_to_num(ldf["Age"].median())
# #     print(ldf["Age"])
# #     imr = Imputer(missing_values='NaN', strategy='median', verbose=0)
# #     imr = imr.fit_transform(ldf["Age"].median)
# #     ldf["Age"] = imr
# #     print(imputed_data)
#     return ldf
#
#
# df = pd.read_csv("train.csv")
# df = func(df)
# # drop = ["Ticket", "Cabin", "Embarked"]
# # X = df.drop("Survived", axis=1).drop(drop, axis=1)
# # y = df["Survived"]
# # df.isnull().any()

# %%
# %%heat
# from sklearn import svm
# clf = svm.SVC()
# clf.fit(X.values, y.values)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-290630e596e3> in <module>()
# ----> 1 get_ipython().run_cell_magic('heat', '', 'from sklearn import svm\nclf = svm.SVC()\nclf.fit(X.values, y.values)')
#
# ~/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2101             magic_arg_s = self.var_expand(line, stack_depth)
#    2102             with self.builtin_trap:
# -> 2103                 result = fn(magic_arg_s, cell)
#    2104             return result
#    2105
#
# <decorator-gen-126> in heat(self, line, cell)
#
# ~/anaconda3/lib/python3.6/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/anaconda3/lib/python3.6/site-packages/heat.py in heat(self, line, cell)
#      61
#      62         pyheat = PyHeat(tmp_file)
# ---> 63         pyheat.create_heatmap()
#      64         pyheat.show_heatmap(output_file=filename)
#      65         pyheat.close_heatmap()
#
# ~/anaconda3/lib/python3.6/site-packages/pyheat/pyheat.py in create_heatmap(self)
#      44         """Method to define the heatmap using profile data."""
#      45         # Profile the file.
# ---> 46         self.__profile_file()
#      47         # Map profile stats to heatmap data.
#      48         self.__fetch_heatmap_data_from_profile()
#
# ~/anaconda3/lib/python3.6/site-packages/pyheat/pyheat.py in __profile_file(self)
#      71         self.line_profiler = pprofile.Profile()
#      72         self.line_profiler.runfile(
# ---> 73             open(self.pyfile.path, 'r'), {}, self.pyfile.path)
#      74
#      75     def __get_line_profile_data(self):
#
# ~/anaconda3/lib/python3.6/site-packages/pprofile.py in runfile(self, fd, argv, fd_name, compile_flags, dont_inherit, globals)
#     606         try:
#     607             sys.argv[:] = argv
# --> 608             return self.runctx(code, ctx_globals, None)
#     609         finally:
#     610             sys.argv[:] = original_sys_argv
#
# ~/anaconda3/lib/python3.6/site-packages/pprofile.py in runctx(self, cmd, globals, locals)
#     586         """Similar to profile.Profile.runctx ."""
#     587         with self():
# --> 588             exec(cmd, globals, locals)
#     589         return self
#     590
#
# ~/src/github.com/shokohara/kaggle-titanic/jupyter/ipython_cell_input.py in <module>()
#       1 from sklearn import svm
#       2 clf = svm.SVC()
# ----> 3 clf.fit(X.values, y.values)
#
# NameError: name 'X' is not defined
